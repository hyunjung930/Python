# %%
fp ='/content/drive/MyDrive/python/demo.txt'
fs = open(fp,'r')
data = fs.read()
fs.close()
print(data)
# Out:
# 제발 들어가줘

# %%
fp ='/content/drive/MyDrive/python/demo2.txt'
fs = open(fp,'w')
fs.write("제발 들어가줘")
fs.close()

# %%
fp ='/content/drive/MyDrive/python/demo2.txt'
fs = open(fp,'r')
data = fs.read()
fs.close()
print(data)
# Out:
# 제발 들어가줘

# %% [markdown]
# # 맛보기

# %%
import pandas as pd
mr = pd.read_csv('/content/drive/MyDrive/python/mushrooms.csv')
mr
# Out:
#      class cap-shape cap-surface  ... spore-print-color population habitat
# 0        p         x           s  ...                 k          s       u
# 1        e         x           s  ...                 n          n       g
# 2        e         b           s  ...                 n          n       m
# 3        p         x           y  ...                 k          s       u
# 4        e         x           s  ...                 n          a       g
# ...    ...       ...         ...  ...               ...        ...     ...
# 8119     e         k           s  ...                 b          c       l
# 8120     e         x           s  ...                 b          v       l
# 8121     e         f           s  ...                 b          c       l
# 8122     p         k           y  ...                 w          v       l
# 8123     e         x           s  ...                 o          c       l
#
# [8124 rows x 23 columns]

# %%
mcs =mr['class']
mcs
# Out:
# 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object
