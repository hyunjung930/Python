# %% [markdown]
# # if else
# if 조건:
#
# .... 조건이 참일 때 수행할 구문
#
# else:
#
# .... 조건이 거짓일 때 수행할 구문

# %%
num = int(input("정수: "))
if num%2==0:
   print("짝수")
else:
  print("홀수")
print("...")
# Out:
# 정수: 44
# 짝수
# ...

# %% [markdown]
# # if elif else
# if 조건1:
#
# ... 조건1이 참일 때 수행할 구문
#
# elif 조건2:
#
# ...조건 2가 참일 때 수행할 구문
#
# .
# .
# .
# else:
#
# ... 모든 조건이 거짓일 때 수행할 구문

# %%
score = int(input("국어점수:"))
if score>=90:
  print("A")
elif score>=80:
  print("B")
elif score>=70:
  print("C")
elif score>=60:
 print("D")
else:
  print("F")
print("....")
# Out:
# 국어점수:85
# B
# ....
